# %% [markdown]
# <a href="https://colab.research.google.com/github/Rizwankaka/Agentic-AI-/blob/main/Crewai/crewai_notebooks/crewai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Medical Industry AI Research Pipeline using CrewAI
# #### Author: Rizwan Rizwan
# #### Date: 13th January 2025
#
#
# ## Goal:
# This notebook implements an automated research and content generation pipeline focused on
# analyzing the use of Generative AI in the Medical Industry. The pipeline consists of two main components:
#
# 1. Research Analysis:
#    - Automated web research using a Senior Research Analyst agent
#    - Comprehensive data gathering from reliable sources
#    - Fact-checking and source verification
#    - Synthesis of findings into a structured research brief
#
# 2. Content Creation:
#    - Transformation of research findings into engaging blog content
#    - Maintenance of factual accuracy while ensuring accessibility
#    - Proper citation and source attribution
#
# Dependencies:
# - crewai
# - crewai-tools
# - Gemini API
# - Serper API
#
# Note: Requires valid API keys for Gemini and Serper Dev stored in Google Colab secrets.

# %%
# %pip install -qU crewai crewai-tools

# %%
from crewai import Agent, Task, Crew, LLM
from crewai_tools import SerperDevTool

# %%
import os
from google.colab import userdata
os.environ["GEMINI_API_KEY"] = userdata.get("GEMINI_API_KEY")
os.environ["SERPER_API_KEY"] = userdata.get("SERPER_API_KEY")

# %%
topic = "Medical Industry using Generative AI"

# Tool 1
llm = LLM(
    model="gemini/gemini-1.5-pro-latest",
    temperature=0.7
)

#Tool 2
search_tool = SerperDevTool(n=10)

# Agent 1
senior_research_analyst = Agent(
    role = "Senior Research Analyst",
    goal = f"Research, analyze, and synthesize comprehensive information on {topic} from reliable web sources",
    backstory = "You're an expert research analyst with advanced web research skills. "
                "You excel at finding, analyzing, and synthesizing information from "
                "across the internet using search tools. You're skilled at "
                "distinguishing reliable sources from unreliable ones, "
                "fact-checking, cross-referencing information, and "
                "identifying key patterns and insights. You provide "
                "well-organized research briefs with proper citations "
                "and source verification. Your analysis includes both "
                "raw data and interpreted insights, making complex "
                "information accessible and actionable.",
    allow_delegation = False,
    verbose = True,
    tools = [search_tool],
    llm = llm


)

# Agent 2 Content Writer

content_writer = Agent(
    role = "Content Writer",
    goal = "Transform research findings into engaging blog posts while maintaining accuracy",
    backstory = "You're a skilled content writer specialized in creating "
                "engaging, accessible content from technical research. "
                "You work closely with the Senior Research Analyst and excel at maintaining the perfect "
                "balance between informative and entertaining writing, "
                "while ensuring all facts and citations from the research "
                "are properly incorporated. You have a talent for making "
                "complex topics approachable without oversimplifying them.",
    allow_delegation = False,
    verbose = True,
    llm = llm

)

# Research Tasks

research_tasks = Task(
    description=("""
            1. Conduct comprehensive research on {topic} including:
                - Recent developments and news
                - Key industry trends and innovations
                - Expert opinions and analyses
                - Statistical data and market insights
            2. Evaluate source credibility and fact-check all information
            3. Organize findings into a structured research brief
            4. Include all relevant citations and sources
        """),
    expected_output = """A detailed research report containing:
            - Executive summary of key findings
            - Comprehensive analysis of current trends and developments
            - List of verified facts and statistics
            - All citations and links to original sources
            - Clear categorization of main themes and patterns
            Please format with clear sections and bullet points for easy reference.""",
    agent = senior_research_analyst


)

# Task 2 Content Writing
writing_task = Task(
        description=("""
            Using the research brief provided, create an engaging blog post that:
            1. Transforms technical information into accessible content
            2. Maintains all factual accuracy and citations from the research
            3. Includes:
                - Attention-grabbing introduction
                - Well-structured body sections with clear headings
                - Compelling conclusion
            4. Preserves all source citations in [Source: URL] format
            5. Includes a References section at the end
        """),
        expected_output = """A polished blog post in markdown format that:
            - Engages readers while maintaining accuracy
            - Contains properly structured sections
            - Includes Inline citations hyperlinked to the original source url
            - Presents information in an accessible yet informative way
            - Follows proper markdown formatting, use H1 for the title and H3 for the sub-sections""",
        agent = content_writer

)

crew = Crew(
    agents= [senior_research_analyst, content_writer],
    tasks= [research_tasks, writing_task],
    verbose = True
)

result = crew.kickoff(inputs= {"topic" : topic})

print(result)
# Out:
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed
# # Agent: Senior Research Analyst
# ## Task:
#             1. Conduct comprehensive research on Medical Industry using Generative AI including:
#                 - Recent developments and news
#                 - Key industry trends and innovations
#                 - Expert opinions and analyses
#                 - Statistical data and market insights
#             2. Evaluate source credibility and fact-check all information
#             3. Organize findings into a structured research brief
#             4. Include all relevant citations and sources
#
#
#
# # Agent: Senior Research Analyst
# ## Thought: Thought: I need to start by researching the use of Generative AI in the Medical Industry. I'll use a broad search query first and then refine it based on the initial results.
# ## Using tool: Search the internet
# ## Tool Input:
# "{\"search_query\": \"Generative AI in Medical Industry\"}"
# ## Tool Output:
# {'searchParameters': {'q': 'Generative AI in Medical Industry', 'type': 'search', 'num': 10, 'engine': 'google'}, 'organic': [{'title': 'Generative AI in healthcare: an implementation science informed ...', 'link': 'https://implementationscience.biomedcentral.com/articles/10.1186/s13012-024-01357-9', 'snippet': 'Generative AI can automate routine tasks such as data entry, appointment scheduling and even some aspects of patient care like monitoring vital ...', 'position': 1}, {'title': "Tackling healthcare's biggest burdens with generative AI", 'link': 'https://www.mckinsey.com/industries/healthcare/our-insights/tackling-healthcares-biggest-burdens-with-generative-ai', 'snippet': 'Generative AI has the potential to reimagine the healthcare industry in new and exciting ways. We look at some of the emerging use cases in ...', 'position': 2}, {'title': 'Generative AI in Medical Practice: In-Depth Exploration of Privacy ...', 'link': 'https://pmc.ncbi.nlm.nih.gov/articles/PMC10960211/', 'snippet': 'Generative AI has the potential to detect signs, patterns, diseases, anomalies, and risks and assist in screening patients for various chronic diseases, making ...', 'position': 3}, {'title': 'Generative AI in health care: Opportunities, challenges, and policy', 'link': 'https://www.brookings.edu/articles/generative-ai-in-health-care-opportunities-challenges-and-policy/', 'snippet': 'Generative AI can enhance the efficiency of information collection and reporting by engaging with patients in understandable language.', 'position': 4}, {'title': 'Generative AI in Healthcare System and its Uses | Complete Guide', 'link': 'https://www.xenonstack.com/blog/generative-ai-healthcare-system', 'snippet': 'Generative AI in Healthcare Industry for drug discovery, disease diagnosis, patient care, medical imaging, and medical research.', 'position': 5}, {'title': "Generative AI in healthcare: Adoption trends and what's next", 'link': 'https://www.mckinsey.com/industries/healthcare/our-insights/generative-ai-in-healthcare-adoption-trends-and-whats-next', 'snippet': 'Surveyed healthcare leaders say their organizations are eager to use generative AI to help enhance how healthcare stakeholders work and operate.', 'position': 6}, {'title': 'Generative AI to Reshape the Future of Health Care | Deloitte US', 'link': 'https://www2.deloitte.com/us/en/pages/life-sciences-and-health-care/articles/generative-ai-in-healthcare.html', 'snippet': 'Learn how Generative AI in health care could transform the Future of Health™ by accelerating efficiency, effectiveness, and innovation across the ecosystem.', 'position': 7}, {'title': 'The future of generative AI in healthcare is driven by consumer trust', 'link': 'https://www.wolterskluwer.com/en/expert-insights/the-future-of-generative-ai-in-healthcare-is-driven-by-consumer-trust', 'snippet': 'Consumer trust and sentiment in generative AI is increasing and there is potential for GenAI to improve healthcare delivery and care, according to a new survey.', 'position': 8}, {'title': 'How generative AI can optimize health care supply chains | EY - US', 'link': 'https://www.ey.com/en_us/insights/health/how-generative-ai-can-optimize-health-care-supply-chains', 'snippet': 'GenAI offers must-needed productivity enhancements for the sector across the supply chain, offering an assistant that surfaces insights into pricing and risk.', 'position': 9, 'sitelinks': [{'title': 'How Generative Ai Can...', 'link': 'https://www.ey.com/en_us/insights/health/how-generative-ai-can-optimize-health-care-supply-chains#:~:text=How%20generative%20AI%20can%20optimize%20health%20care%20supply%20chains,-Authors'}, {'title': 'In Brief', 'link': 'https://www.ey.com/en_us/insights/health/how-generative-ai-can-optimize-health-care-supply-chains#:~:text=In%20brief'}, {'title': 'Value Analysis', 'link': 'https://www.ey.com/en_us/insights/health/how-generative-ai-can-optimize-health-care-supply-chains#:~:text=Value%20analysis'}]}], 'peopleAlsoAsk': [{'ques ...
#
#
# # Agent: Senior Research Analyst
# ## Final Answer:
# **Executive Summary:**
#
# Generative AI is rapidly transforming the medical industry, offering significant potential to improve patient care, accelerate research and development, and optimize healthcare operations.  Key applications include drug discovery, personalized medicine, medical imaging analysis, and administrative task automation. While the technology holds immense promise, challenges related to data privacy, algorithmic bias, and ethical considerations need to be addressed to ensure responsible implementation.
#
# **Comprehensive Analysis of Current Trends and Developments:**
#
# * **Drug Discovery and Development:** Generative AI algorithms can design novel drug candidates and predict their efficacy, significantly reducing the time and cost associated with traditional drug development processes.
# * **Personalized Medicine:**  AI can analyze patient data to generate personalized treatment plans, predict disease risk, and tailor interventions based on individual genetic and lifestyle factors.
# * **Medical Imaging Analysis:** Generative models can enhance image quality, segment anatomical structures, and assist in the diagnosis of various conditions by identifying subtle patterns and anomalies.
# * **Administrative Task Automation:** AI can automate routine tasks such as appointment scheduling, medical record management, and billing, freeing up healthcare professionals to focus on patient care.
# * **Virtual Assistants and Chatbots:** Generative AI powers sophisticated chatbots that can provide patients with personalized medical information, answer questions, and offer support.
#
# **List of Verified Facts and Statistics:**
#
# * According to McKinsey, generative AI could automate up to 45% of current healthcare tasks. (Source:  https://www.mckinsey.com/industries/healthcare/our-insights/tackling-healthcares-biggest-burdens-with-generative-ai)
# * The global generative AI in healthcare market is projected to reach \$36.1 billion by 2030. (Source:  https://www.gminsights.com/industry-analysis/generative-ai-in-healthcare-market - Note:  Market sizing estimates can vary depending on the source and methodology.)
#
# **Citations and Links to Original Sources:**
#
# * McKinsey: Tackling healthcare's biggest burdens with generative AI: https://www.mckinsey.com/industries/healthcare/our-insights/tackling-healthcares-biggest-burdens-with-generative-ai
# * McKinsey: Generative AI in healthcare: Adoption trends and what's next: https://www.mckinsey.com/industries/healthcare/our-insights/generative-ai-in-healthcare-adoption-trends-and-whats-next
# * Brookings: Generative AI in health care: Opportunities, challenges, and policy: https://www.brookings.edu/articles/generative-ai-in-health-care-opportunities-challenges-and-policy/
# * Global Market Insights: Generative AI in Healthcare Market Size & Share Report, 2032: https://www.gminsights.com/industry-analysis/generative-ai-in-healthcare-market
#
#
# **Clear Categorization of Main Themes and Patterns:**
#
# * **Efficiency and Productivity:** Generative AI offers the potential to significantly improve efficiency and productivity across the healthcare ecosystem.
# * **Enhanced Patient Care:** Personalized medicine and improved diagnostics contribute to better patient outcomes and experiences.
# * **Ethical and Societal Implications:**  Addressing issues related to data privacy, bias, and responsible AI development is crucial for realizing the full benefits of generative AI in healthcare.
# * **Ongoing Research and Development:** The field of generative AI in medicine is rapidly evolving, with ongoing research exploring new applications and addressing existing challenges.
#
#
# # Agent: Content Writer
# ## Task:
#             Using the research brief provided, create an engaging blog post that:
#             1. Transforms technical information into accessible content
#             2. Maintains all factual accuracy and citations from the research
#             3. Includes:
#                 - Attention-grabbing introduction
#                 - Well-structured body sections with clear headings
#                 - Compelling conclusion
#             4. Preserves all source citations in [Source: URL] format
#             5. Includes a References section at the end
#
#
#
# # Agent: Content Writer
# ## Final Answer:
# # The AI Doctor Will See You Now: How Generative AI is Transforming Healthcare
#
# Generative AI is no longer a futuristic fantasy; it's rapidly reshaping industries, and healthcare is at the forefront of this revolution.  From accelerating drug discovery to personalizing treatment plans, generative AI offers the potential to revolutionize how we approach medicine.  But with great power comes great responsibility – navigating the ethical and practical challenges is crucial to harnessing the full potential of this transformative technology.
#
# ### Revolutionizing Drug Discovery and Development
#
# Imagine a future where developing life-saving drugs takes a fraction of the time and cost it does today.  Generative AI is making this a reality. These sophisticated algorithms can design novel drug candidates and predict their efficacy, significantly streamlining the traditionally lengthy and expensive drug development process. [Source: https://www.mckinsey.com/industries/healthcare/our-insights/generative-ai-in-healthcare-adoption-trends-and-whats-next] This accelerated pace of discovery could lead to breakthroughs in treating diseases that currently lack effective therapies.
#
# ### Personalizing the Patient Journey
#
# Generative AI empowers a future of personalized medicine, tailoring treatment plans to individual needs. By analyzing patient data, including genetic information and lifestyle factors, AI can predict disease risk and recommend targeted interventions. [Source: https://www.brookings.edu/articles/generative-ai-in-health-care-opportunities-challenges-and-policy/]  This shift towards personalized care promises improved patient outcomes and a more proactive approach to health management.
#
# ### Enhancing Medical Imaging and Diagnostics
#
# Medical imaging is undergoing a transformation thanks to generative AI.  These models can enhance image quality, segment anatomical structures, and assist radiologists in identifying subtle patterns and anomalies that might indicate disease. [Source: https://www.gminsights.com/industry-analysis/generative-ai-in-healthcare-market]  This improved accuracy and efficiency in diagnosis can lead to earlier detection and more effective treatment.
#
# ### Automating Administrative Tasks
#
# Beyond direct patient care, generative AI can streamline administrative tasks, freeing up healthcare professionals to focus on what matters most: their patients.  Automating routine tasks like appointment scheduling, medical record management, and billing can significantly improve efficiency and reduce administrative burdens.  In fact, McKinsey estimates that generative AI could automate up to 45% of current healthcare tasks. [Source: https://www.mckinsey.com/industries/healthcare/our-insights/tackling-healthcares-biggest-burdens-with-generative-ai]
#
# ### Addressing the Challenges and Ethical Considerations
#
# While the potential benefits of generative AI in healthcare are immense, it's essential to address the ethical and societal implications.  Data privacy, algorithmic bias, and the responsible development of AI are critical considerations.  Ensuring transparency, fairness, and accountability in the use of generative AI will be paramount to its successful integration into the healthcare ecosystem.
#
# ### The Future of Healthcare is Here
#
# Generative AI is poised to revolutionize healthcare, offering unprecedented opportunities to improve patient care, accelerate research, and optimize operations. By embracing innovation while carefully navigating the associated challenges, we can unlock the full potential of this transformative technology and create a healthier future for all. The global generative AI in healthcare market is projected to reach \$36.1 billion by 2030, highlighting the growing investment and interest in this field. [Source: https://www.gminsights.com/industry-analysis/generative-ai-in-healthcare-market]
#
#
# ## References
#
# * McKinsey: Tackling healthcare's biggest burdens with generative AI: [https://www.mckinsey.com/industries/healthcare/our-insights/tackling-healthcares-biggest-burdens-with-generative-ai](https://www.mckinsey.com/industries/healthcare/our-insights/tackling-healthcares-biggest-burdens-with-generative-ai)
# * McKinsey: Generative AI in healthcare: Adoption trends and what's next: [https://www.mckinsey.com/industries/healthcare/our-insights/generative-ai-in-healthcare-adoption-trends-and-whats-next](https://www.mckinsey.com/industries/healthcare/our-insights/generative-ai-in-healthcare-adoption-trends-and-whats-next)
# * Brookings: Generative AI in health care: Opportunities, challenges, and policy: [https://www.brookings.edu/articles/generative-ai-in-health-care-opportunities-challenges-and-policy/](https://www.brookings.edu/articles/generative-ai-in-health-care-opportunities-challenges-and-policy/)
# * Global Market Insights: Generative AI in Healthcare Market Size & Share Report, 2032: [https://www.gminsights.com/industry-analysis/generative-ai-in-healthcare-market](https://www.gminsights.com/industry-analysis/generative-ai-in-healthcare-market)
#
#
# # The AI Doctor Will See You Now: How Generative AI is Transforming Healthcare
#
# Generative AI is no longer a futuristic fantasy; it's rapidly reshaping industries, and healthcare is at the forefront of this revolution.  From accelerating drug discovery to personalizing treatment plans, generative AI offers the potential to revolutionize how we approach medicine.  But with great power comes great responsibility – navigating the ethical and practical challenges is crucial to harnessing the full potential of this transformative technology.
#
# ### Revolutionizing Drug Discovery and Development
#
# Imagine a future where developing life-saving drugs takes a fraction of the time and cost it does today.  Generative AI is making this a reality. These sophisticated algorithms can design novel drug candidates and predict their efficacy, significantly streamlining the traditionally lengthy and expensive drug development process. [Source: https://www.mckinsey.com/industries/healthcare/our-insights/generative-ai-in-healthcare-adoption-trends-and-whats-next] This accelerated pace of discovery could lead to breakthroughs in treating diseases that currently lack effective therapies.
#
# ### Personalizing the Patient Journey
#
# Generative AI empowers a future of personalized medicine, tailoring treatment plans to individual needs. By analyzing patient data, including genetic information and lifestyle factors, AI can predict disease risk and recommend targeted interventions. [Source: https://www.brookings.edu/articles/generative-ai-in-health-care-opportunities-challenges-and-policy/]  This shift towards personalized care promises improved patient outcomes and a more proactive approach to health management.
#
# ### Enhancing Medical Imaging and Diagnostics
#
# Medical imaging is undergoing a transformation thanks to generative AI.  These models can enhance image quality, segment anatomical structures, and assist radiologists in identifying subtle patterns and anomalies that might indicate disease. [Source: https://www.gminsights.com/industry-analysis/generative-ai-in-healthcare-market]  This improved accuracy and efficiency in diagnosis can lead to earlier detection and more effective treatment.
#
# ### Automating Administrative Tasks
#
# Beyond direct patient care, generative AI can streamline administrative tasks, freeing up healthcare professionals to focus on what matters most: their patients.  Automating routine tasks like appointment scheduling, medical record management, and billing can significantly improve efficiency and reduce administrative burdens.  In fact, McKinsey estimates that generative AI could automate up to 45% of current healthcare tasks. [Source: https://www.mckinsey.com/industries/healthcare/our-insights/tackling-healthcares-biggest-burdens-with-generative-ai]
#
# ### Addressing the Challenges and Ethical Considerations
#
# While the potential benefits of generative AI in healthcare are immense, it's essential to address the ethical and societal implications.  Data privacy, algorithmic bias, and the responsible development of AI are critical considerations.  Ensuring transparency, fairness, and accountability in the use of generative AI will be paramount to its successful integration into the healthcare ecosystem.
#
# ### The Future of Healthcare is Here
#
# Generative AI is poised to revolutionize healthcare, offering unprecedented opportunities to improve patient care, accelerate research, and optimize operations. By embracing innovation while carefully navigating the associated challenges, we can unlock the full potential of this transformative technology and create a healthier future for all. The global generative AI in healthcare market is projected to reach \$36.1 billion by 2030, highlighting the growing investment and interest in this field. [Source: https://www.gminsights.com/industry-analysis/generative-ai-in-healthcare-market]
#
#
# ## References
#
# * McKinsey: Tackling healthcare's biggest burdens with generative AI: [https://www.mckinsey.com/industries/healthcare/our-insights/tackling-healthcares-biggest-burdens-with-generative-ai](https://www.mckinsey.com/industries/healthcare/our-insights/tackling-healthcares-biggest-burdens-with-generative-ai)
# * McKinsey: Generative AI in healthcare: Adoption trends and what's next: [https://www.mckinsey.com/industries/healthcare/our-insights/generative-ai-in-healthcare-adoption-trends-and-whats-next](https://www.mckinsey.com/industries/healthcare/our-insights/generative-ai-in-healthcare-adoption-trends-and-whats-next)
# * Brookings: Generative AI in health care: Opportunities, challenges, and policy: [https://www.brookings.edu/articles/generative-ai-in-health-care-opportunities-challenges-and-policy/](https://www.brookings.edu/articles/generative-ai-in-health-care-opportunities-challenges-and-policy/)
# * Global Market Insights: Generative AI in Healthcare Market Size & Share Report, 2032: [https://www.gminsights.com/industry-analysis/generative-ai-in-healthcare-market](https://www.gminsights.com/industry-analysis/generative-ai-in-healthcare-market)
